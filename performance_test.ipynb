# %%
import sys
import json
from openai import OpenAI
from LLama_index import initialize_index, get_top_matches
from SNKER_v1 import analyze_sentiment, generate_personalized_recommendation
from typing import Dict, List, Tuple
import pandas as pd
from datetime import datetime

# Initialize OpenAI client
client = OpenAI(api_key="")

def create_customer_agent():
    """Create customer agent prompt"""
    system_prompt = """
    You are a customer looking for sneakers. Your task is to evaluate if the salesperson's recommendation fully addresses your initial requirements.

    Evaluation rules:
    1. Carefully compare the recommendation against your initial requirements
    2. Consider the recommendation satisfactory ONLY IF it addresses ALL aspects of your initial requirements
    3. If ALL requirements are met:
       - Set "satisfied" to true
       - Set "end_conversation" to true
       - Express satisfaction in your response
    4. If ANY requirement is not addressed:
       - Set "satisfied" to false
       - Set "end_conversation" to false
       - In your response, clearly state which requirements were not met
    5. Maximum 3 conversation turns

    Return response in JSON format:
    {
        "satisfied": true/false,
        "response": "your response",
        "end_conversation": true/false,
        "requirements_met": ["list of met requirements"],
        "requirements_missing": ["list of unmet requirements"]
    }

    Example:
    If initial request was "comfortable for walking and stylish", and recommendation only addresses comfort,
    you should identify that style was not addressed and request more information about style aspects.
    """
    return system_prompt

def evaluate_conversation(initial_query, recommendation):
    """Evaluate the conversation"""
    try:
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": create_customer_agent()},
                {"role": "user", "content": f"Initial requirement: {initial_query}\nSalesperson recommendation: {recommendation}"}
            ],
            response_format={ "type": "json_object" }
        )
        
        # Parse the response
        evaluation = json.loads(response.choices[0].message.content)
        
        # # Print the conversation details
        # print("\n=== Conversation Turn ===")
        # print(f"Customer's initial request: {initial_query}")
        # print(f"Salesperson's recommendation: {recommendation}")
        # print(f"Customer's response: {evaluation['response']}")
        # print(f"Customer satisfied: {'Yes' if evaluation['satisfied'] else 'No'}")
        # print(f"End conversation: {'Yes' if evaluation['end_conversation'] else 'No'}")
        # print("=====================\n")
        
        return evaluation
    except Exception as e:
        print(f"Evaluation error: {e}")
        return None
    
def read_test_cases_by_scenario(filename: str) -> Dict[str, List[str]]:
    """Read test cases from file and organize them by scenario"""
    scenarios = {}
    current_scenario = None
    
    with open(filename, 'r') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            if line.startswith('#'):
                # New scenario found
                current_scenario = line.replace('#', '').strip()
                scenarios[current_scenario] = []
            elif current_scenario and line[0].isdigit():
                # Remove the numbering (e.g., "1. ") from the line
                test_case = line[line.find(' ')+1:].strip()
                scenarios[current_scenario].append(test_case)
    
    return scenarios

def run_test_case(query, index):
    """Run a single test case"""
    conversation_history = []
    max_turns = 3
    current_turn = 0
    current_query = query
    
    while current_turn < max_turns:
        # Get recommendations
        top_matches, summary, flag = get_top_matches(current_query, " ".join(conversation_history), index)
        if not top_matches:
            return False, current_turn + 1
            
        # Generate recommendation response
        sentiment = analyze_sentiment(current_query)
        recommendation = generate_personalized_recommendation(summary, top_matches[0], sentiment)
        
        # Evaluate recommendation
        evaluation = evaluate_conversation(query, recommendation)
        if evaluation is None:
            return False, current_turn + 1
            
        conversation_history.append(current_query)
        
        if evaluation['satisfied'] or evaluation['end_conversation']:
            return True, current_turn + 1
            
        current_query = evaluation['response']
        current_turn += 1
    
    return False, max_turns


def create_evaluator_agent():
    """Create the evaluator system prompt"""
    system_prompt = """
    You are a professional recommendation system evaluator. Please evaluate the system's responses 
    across the following dimensions:
    
    1. Relevance: How well the recommendation matches user needs (1-5 points)
    2. Completeness: Whether all user requirements are addressed (1-5 points)
    3. Personalization: Level of recommendation personalization (1-5 points)
    4. Expertise: Level of product knowledge demonstrated (1-5 points)
    5. Language: Clarity and naturalness of expression (1-5 points)
    
    Return evaluation in JSON format:
    {
        "scores": {
            "relevance": float,
            "completeness": float,
            "personalization": float,
            "expertise": float,
            "language": float,
            "average": float
        },
        "analysis": {
            "strengths": ["strength1", "strength2"...],
            "weaknesses": ["weakness1", "weakness2"...],
            "suggestions": ["suggestion1", "suggestion2"...]
        }
    }
    """
    return system_prompt

def g_evaluate(query: str, recommendation: str) -> Dict:
    """Perform G-Evaluation assessment"""
    try:
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": create_evaluator_agent()},
                {"role": "user", "content": f"User Query: {query}\nSystem Recommendation: {recommendation}"}
            ],
            response_format={ "type": "json_object" }
        )
        
        return json.loads(response.choices[0].message.content)
    except Exception as e:
        print(f"G-Evaluation error: {e}")
        return None

def run_evaluation_batch(test_cases_by_scenario: Dict[str, List[Tuple[str, str]]]) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """Run batch G-Evaluation and generate reports by scenario"""
    all_results = []
    scenario_summaries = []
    
    for scenario, cases in test_cases_by_scenario.items():
        scenario_results = []
        
        for query, recommendation in cases:
            evaluation = g_evaluate(query, recommendation)
            if evaluation:
                result = {
                    'scenario': scenario,
                    'query': query,
                    'recommendation': recommendation,
                    **evaluation['scores'],
                    'strengths': '; '.join(evaluation['analysis']['strengths']),
                    'weaknesses': '; '.join(evaluation['analysis']['weaknesses']),
                    'suggestions': '; '.join(evaluation['analysis']['suggestions'])
                }
                scenario_results.append(result)
                all_results.append(result)
        
        # Calculate scenario averages
        if scenario_results:
            df_scenario = pd.DataFrame(scenario_results)
            scenario_summary = {
                'Scenario': scenario,
                'Average Relevance': df_scenario['relevance'].mean(),
                'Average Completeness': df_scenario['completeness'].mean(),
                'Average Personalization': df_scenario['personalization'].mean(),
                'Average Expertise': df_scenario['expertise'].mean(),
                'Average Language': df_scenario['language'].mean(),
                'Overall Average': df_scenario['average'].mean()
            }
            scenario_summaries.append(scenario_summary)
    
    return pd.DataFrame(all_results), pd.DataFrame(scenario_summaries)

# %%
def main():
    # Initialize index
    index = initialize_index()
    
    # Read test cases by scenario
    test_cases_by_scenario = read_test_cases_by_scenario('input_test.txt')
    
    # Organize test pairs by scenario
    test_pairs_by_scenario = {}
    results_by_scenario = {}
    
    for scenario, test_cases in test_cases_by_scenario.items():
        test_pairs_by_scenario[scenario] = []
        scenario_results = []
        
        for test_case in test_cases:
            # Get first-round recommendation
            top_matches, summary, flag = get_top_matches(test_case, "", index)
            if top_matches:
                sentiment = analyze_sentiment(test_case)
                recommendation = generate_personalized_recommendation(summary, top_matches[0], sentiment)
                test_pairs_by_scenario[scenario].append((test_case, recommendation))
                
                success, turns = run_test_case(test_case, index)
                scenario_results.append({
                    'query': test_case,
                    'success': success,
                    'turns': turns
                })
        
        results_by_scenario[scenario] = scenario_results
    
    # Print results by scenario
    print("\n=== Test Results by Scenario ===")
    for scenario, results in results_by_scenario.items():
        total_cases = len(results)
        successful_cases = sum(1 for r in results if r['success'])
        success_rate = (successful_cases / total_cases) * 100 if total_cases > 0 else 0
        avg_turns = sum(r['turns'] for r in results) / total_cases if total_cases > 0 else 0
        
        print(f"\n{scenario}:")
        print(f"Total cases: {total_cases}")
        print(f"Success rate: {success_rate:.2f}%")
        print(f"Average turns: {avg_turns:.2f}")
    
    # Run G-Evaluation
    print("\n=== G-Evaluation Results ===")
    detailed_results, scenario_summary = run_evaluation_batch(test_pairs_by_scenario)
    
    # Display scenario summary table
    print("\nScenario Summary:")
    print(scenario_summary.to_string(index=False))
    
    # Save results
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    detailed_results.to_csv(f'g_evaluation_detailed_{timestamp}.csv', index=False)
    scenario_summary.to_csv(f'g_evaluation_summary_{timestamp}.csv', index=False)
    
    print(f"\nDetailed results saved to: g_evaluation_detailed_{timestamp}.csv")
    print(f"Summary results saved to: g_evaluation_summary_{timestamp}.csv")

if __name__ == "__main__":
    main()
# Out:
# Extracted Preferences:
# {
#   "query": [
#     "I need something comfortable for walking around the city all day."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  I need something comfortable for walking around the city all day.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for comfortable shoes for walking around the city all day."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for comfortable shoes for walking around the city all day.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for shoes that I can wear both at the gym and casual outings."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for shoes that I can wear both at the gym and casual outings.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for shoes that I can wear both at the gym and casual outings."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for shoes that I can wear both at the gym and casual outings.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for shoes for daily morning jogs."
#   ],
#   "colors": [],
#   "categories": [
#     "Running"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for shoes for daily morning jogs.
#
# Extracted Preferences:
# {
#   "query": [
#     "Need something for daily morning jogs."
#   ],
#   "colors": [],
#   "categories": [
#     "Running"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Need something for daily morning jogs.
#
# Extracted Preferences:
# {
#   "query": [
#     "I want something that looks vintage but still modern."
#   ],
#   "colors": [],
#   "categories": [],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  I want something that looks vintage but still modern.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is interested in shoes with a vintage but modern look."
#   ],
#   "colors": [],
#   "categories": [],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is interested in shoes with a vintage but modern look.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for sneakers that aren't too flashy but still stylish."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for sneakers that aren't too flashy but still stylish.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for sneakers that aren't too flashy but still stylish."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for sneakers that aren't too flashy but still stylish.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for shoes with a cool streetwear vibe."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for shoes with a cool streetwear vibe.
#
# Extracted Preferences:
# {
#   "query": [
#     "Want some cool streetwear vibes in shoes."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Want some cool streetwear vibes in shoes.
#
# Extracted Preferences:
# {
#   "query": [
#     "User needs supportive shoes due to foot pain after long walks."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User needs supportive shoes due to foot pain after long walks.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user experiences foot pain after long walks and needs supportive shoes."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user experiences foot pain after long walks and needs supportive shoes.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for shoes that are light and breathable for summer."
#   ],
#   "colors": [],
#   "categories": [],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for shoes that are light and breathable for summer.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for light and breathable shoes for summer."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for light and breathable shoes for summer.
#
# Extracted Preferences:
# {
#   "query": [
#     "Need shoes that don't make my feet sweaty."
#   ],
#   "colors": [],
#   "categories": [],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Need shoes that don't make my feet sweaty.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user wants shoes that prevent their feet from sweating."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user wants shoes that prevent their feet from sweating.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for shoes with dedicated technologies or features aimed at moisture control or enhanced breathability to minimize sweat."
#   ],
#   "colors": [],
#   "categories": [],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for shoes with dedicated technologies or features aimed at moisture control or enhanced breathability to minimize sweat.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for sneakers that can be worn to work and look stylish."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for sneakers that can be worn to work and look stylish.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for sneakers that are appropriate for work and also look stylish."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for sneakers that are appropriate for work and also look stylish.
#
# Extracted Preferences:
# {
#   "query": [
#     "Want something suitable for both indoor and outdoor activities."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Want something suitable for both indoor and outdoor activities.
#
# Extracted Preferences:
# {
#   "query": [
#     "Want something suitable for both indoor and outdoor activities"
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Want something suitable for both indoor and outdoor activities
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for shoes for casual parties"
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for shoes for casual parties
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for shoes to wear at casual parties."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for shoes to wear at casual parties.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user wants shoes that are comfortable and look good with jeans."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user wants shoes that are comfortable and look good with jeans.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for comfortable shoes that also look good with jeans."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for comfortable shoes that also look good with jeans.
#
# Extracted Preferences:
# {
#   "query": [
#     "Need breathable shoes for summer that aren't too sporty looking."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Need breathable shoes for summer that aren't too sporty looking.
#
# Extracted Preferences:
# {
#   "query": [
#     "Need breathable shoes for summer that aren't too sporty looking."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Need breathable shoes for summer that aren't too sporty looking.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for stylish sneakers for light exercise"
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle",
#     "Running"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for stylish sneakers for light exercise
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for stylish sneakers suitable for light exercise."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle",
#     "Running"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for stylish sneakers suitable for light exercise.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user has flat feet and needs comfortable shoes."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user has flat feet and needs comfortable shoes.
#
# Extracted Preferences:
# {
#   "query": [
#     "Searching for comfortable shoes due to flat feet"
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Searching for comfortable shoes due to flat feet
#
# Extracted Preferences:
# {
#   "query": [
#     "The user needs shoes that provide good ankle support for walking."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user needs shoes that provide good ankle support for walking.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for shoes that provide good ankle support due to pain when walking."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for shoes that provide good ankle support due to pain when walking.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for shoes that provide comfort and prevent foot fatigue during long shifts."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for shoes that provide comfort and prevent foot fatigue during long shifts.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for shoes that won't make their feet tired during long shifts."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for shoes that won't make their feet tired during long shifts.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for shoes suitable for rainy weather that still have a nice appearance"
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for shoes suitable for rainy weather that still have a nice appearance
#
# Extracted Preferences:
# {
#   "query": [
#     "Need something good for rainy weather but still looks nice."
#   ],
#   "colors": [],
#   "categories": [
#     "Boot"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Need something good for rainy weather but still looks nice.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for comfortable sneakers suitable for hot summer days."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for comfortable sneakers suitable for hot summer days.
#
# Extracted Preferences:
# {
#   "query": [
#     "User wants comfortable sneakers for hot summer days."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User wants comfortable sneakers for hot summer days.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for something suitable for spring weather."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for something suitable for spring weather.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for shoes suitable for spring weather."
#   ],
#   "colors": [],
#   "categories": [],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for shoes suitable for spring weather.
#
# === Test Results by Scenario ===
#
# Activity/Purpose Based:
# Total cases: 3
# Success rate: 100.00%
# Average turns: 1.00
#
# Style/Appearance Based:
# Total cases: 3
# Success rate: 100.00%
# Average turns: 1.00
#
# Comfort/Experience Based:
# Total cases: 3
# Success rate: 100.00%
# Average turns: 1.33
#
# Occasion Based:
# Total cases: 3
# Success rate: 100.00%
# Average turns: 1.00
#
# Mixed Requirements:
# Total cases: 3
# Success rate: 100.00%
# Average turns: 1.00
#
# Specific Problem Based:
# Total cases: 3
# Success rate: 100.00%
# Average turns: 1.00
#
# Weather/Season Based:
# Total cases: 3
# Success rate: 100.00%
# Average turns: 1.00
#
# === G-Evaluation Results ===
#
# Scenario Summary:
#                 Scenario  Average Relevance  Average Completeness  Average Personalization  Average Expertise  Average Language  Overall Average
#   Activity/Purpose Based           4.333333              4.166667                 2.833333           4.333333          4.666667         4.066667
#   Style/Appearance Based           4.500000              4.500000                 3.333333           4.666667          5.000000         4.400000
# Comfort/Experience Based           3.666667              4.166667                 2.666667           4.333333          4.666667         3.900000
#           Occasion Based           4.500000              4.000000                 3.000000           4.500000          4.833333         4.166667
#       Mixed Requirements           4.333333              4.333333                 3.000000           4.666667          5.000000         4.266667
#   Specific Problem Based           3.833333              3.666667                 2.666667           4.000000          4.666667         3.766667
#     Weather/Season Based           3.833333              3.500000                 2.500000           4.333333          4.666667         3.766667
#
# Detailed results saved to: g_evaluation_detailed_20241124_192608.csv
# Summary results saved to: g_evaluation_summary_20241124_192608.csv
