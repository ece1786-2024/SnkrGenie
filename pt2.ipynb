# %%
import sys
import json
from openai import OpenAI
from LLama_index import initialize_index, get_top_matches
from SNKER_v1 import analyze_sentiment, generate_personalized_recommendation
from typing import Dict, List, Tuple
import pandas as pd
from datetime import datetime

client = OpenAI(api_key="")
        
def create_customer_agent():
    """Create customer agent prompt"""
    system_prompt = """
    You are a customer looking for sneakers. Your task is to evaluate if the salesperson's recommendation fully addresses your initial requirements.

    Evaluation rules:
    1. Carefully compare the recommendation against your initial requirements
    2. Consider the recommendation satisfactory ONLY IF it addresses ALL aspects of your initial requirements
    3. If ALL requirements are met:
       - Set "satisfied" to true
       - Set "end_conversation" to true
       - Express satisfaction in your response
    4. If ANY requirement is not addressed:
       - Set "satisfied" to false
       - Set "end_conversation" to false
       - In your response, clearly state which requirements were not met
    5. Maximum 3 conversation turns

    Return response in JSON format:
    {
        "satisfied": true/false,
        "response": "your response",
        "end_conversation": true/false,
        "requirements_met": ["list of met requirements"],
        "requirements_missing": ["list of unmet requirements"]
    }

    Example:
    If initial request was "comfortable for walking and stylish", and recommendation only addresses comfort,
    you should identify that style was not addressed and request more information about style aspects.
    """
    return system_prompt

def evaluate_conversation(initial_query, recommendation):
    """Evaluate the conversation"""
    try:
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": create_customer_agent()},
                {"role": "user", "content": f"Initial requirement: {initial_query}\nSalesperson recommendation: {recommendation}"}
            ],
            response_format={ "type": "json_object" }
        )
        
        # Parse the response
        evaluation = json.loads(response.choices[0].message.content)
        
        # # Print the conversation details
        # print("\n=== Conversation Turn ===")
        # print(f"Customer's initial request: {initial_query}")
        # print(f"Salesperson's recommendation: {recommendation}")
        # print(f"Customer's response: {evaluation['response']}")
        # print(f"Customer satisfied: {'Yes' if evaluation['satisfied'] else 'No'}")
        # print(f"End conversation: {'Yes' if evaluation['end_conversation'] else 'No'}")
        # print("=====================\n")
        
        return evaluation
    except Exception as e:
        print(f"Evaluation error: {e}")
        return None
    
def read_test_cases_by_scenario(filename: str) -> Dict[str, List[List[str]]]:
    """Read test cases from file and organize them by scenario with multi-turn inputs"""
    scenarios = {}
    current_scenario = None

    with open(filename, 'r') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            if line.startswith('#'):
                # New scenario found
                current_scenario = line.replace('#', '').strip()
                scenarios[current_scenario] = []
            elif current_scenario and line[0].isdigit():
                # Split multi-turn inputs by '|'
                test_case_line = line[line.find(' ')+1:].strip()
                test_case = [part.strip() for part in test_case_line.split('|')]
                scenarios[current_scenario].append(test_case)
    
    return scenarios

def run_test_case(query_parts: List[str], index):
    """Run a multi-turn test case"""
    conversation_history = []
    max_turns = len(query_parts)
    current_turn = 0
    current_query = query_parts[0]

    while current_turn < max_turns:
        # Get recommendations
        top_matches, summary, flag = get_top_matches(current_query, " ".join(conversation_history), index)
        if not top_matches:
            return False, current_turn + 1, None

        # Generate recommendation response
        sentiment = analyze_sentiment(current_query)
        recommendation = generate_personalized_recommendation(summary, top_matches[0], sentiment)

        # Evaluate recommendation (query_parts[0] ensures original input is used)
        evaluation = evaluate_conversation(" | ".join(query_parts), recommendation)
        if evaluation is None:
            return False, current_turn + 1, None

        conversation_history.append(current_query)

        # Check if conversation can end
        if evaluation['satisfied'] or evaluation['end_conversation']:
            return True, current_turn + 1, recommendation

        # Move to next turn
        if current_turn + 1 < max_turns:
            current_query = query_parts[current_turn + 1]
        current_turn += 1

    # Return the final response after all turns
    return False, max_turns, recommendation


def create_evaluator_agent():
    """Create the evaluator system prompt"""
    system_prompt = """
    You are a professional recommendation system evaluator. Please evaluate the system's responses 
    across the following dimensions:
    
    1. Relevance: How well the recommendation matches user needs (1-5 points)
    2. Completeness: Whether all user requirements are addressed (1-5 points)
    3. Personalization: Level of recommendation personalization (1-5 points)
    4. Expertise: Level of product knowledge demonstrated (1-5 points)
    5. Language: Clarity and naturalness of expression (1-5 points)
    
    Return evaluation in JSON format:
    {
        "scores": {
            "relevance": float,
            "completeness": float,
            "personalization": float,
            "expertise": float,
            "language": float,
            "average": float
        },
        "analysis": {
            "strengths": ["strength1", "strength2"...],
            "weaknesses": ["weakness1", "weakness2"...],
            "suggestions": ["suggestion1", "suggestion2"...]
        }
    }
    """
    return system_prompt

def g_evaluate(query: str, recommendation: str) -> Dict:
    """Perform G-Evaluation assessment"""
    try:
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": create_evaluator_agent()},
                {"role": "user", "content": f"User Query: {query}\nSystem Recommendation: {recommendation}"}
            ],
            response_format={ "type": "json_object" }
        )
        
        return json.loads(response.choices[0].message.content)
    except Exception as e:
        print(f"G-Evaluation error: {e}")
        return None

def run_evaluation_batch(test_cases_by_scenario: Dict[str, List[List[str]]], index) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """Run batch G-Evaluation and generate reports by scenario"""
    all_results = []
    scenario_summaries = []

    for scenario, cases in test_cases_by_scenario.items():
        scenario_results = []

        for query_parts in cases:
            if len(query_parts) > 3:
                query_parts = query_parts[:3]  
            query = " | ".join(query_parts)  
            top_matches, summary, flag = get_top_matches(query_parts[-1], "", index)
            if not top_matches:
                continue
            sentiment = analyze_sentiment(query_parts[-1])
            recommendation = generate_personalized_recommendation(summary, top_matches[0], sentiment)

            evaluation = g_evaluate(query, recommendation)  # 使用原始 query 进行评估
            if evaluation:
                result = {
                    'scenario': scenario,
                    'query': query,  # 确保输出中的 query 未修改
                    'recommendation': recommendation,
                    **evaluation['scores'],
                    'strengths': '; '.join(evaluation['analysis']['strengths']),
                    'weaknesses': '; '.join(evaluation['analysis']['weaknesses']),
                    'suggestions': '; '.join(evaluation['analysis']['suggestions'])
                }
                scenario_results.append(result)
                all_results.append(result)

        # Calculate scenario averages
        if scenario_results:
            df_scenario = pd.DataFrame(scenario_results)
            scenario_summary = {
                'Scenario': scenario,
                'Average Relevance': df_scenario['relevance'].mean(),
                'Average Completeness': df_scenario['completeness'].mean(),
                'Average Personalization': df_scenario['personalization'].mean(),
                'Average Expertise': df_scenario['expertise'].mean(),
                'Average Language': df_scenario['language'].mean(),
                'Overall Average': df_scenario['average'].mean()
            }
            scenario_summaries.append(scenario_summary)

    return pd.DataFrame(all_results), pd.DataFrame(scenario_summaries)

def main():
    # Initialize index
    index = initialize_index()

    # Read test cases by scenario
    test_cases_by_scenario = read_test_cases_by_scenario('multi_turns_input_test.txt')

    results_by_scenario = {}
    test_pairs_by_scenario = {}
    all_results = []

    for scenario, test_cases in test_cases_by_scenario.items():
        scenario_results = []
        test_pairs_by_scenario[scenario] = []

        for query_parts in test_cases:
            success, turns, final_recommendation = run_test_case(query_parts, index)
            scenario_results.append({
                'query': " | ".join(query_parts),
                'success': success,
                'turns': turns,
                'final_recommendation': final_recommendation
            })

            if final_recommendation:
                test_pairs_by_scenario[scenario].append((" | ".join(query_parts), final_recommendation))

        results_by_scenario[scenario] = scenario_results
        all_results.extend(scenario_results)

    # Print results by scenario
    print("\n=== Test Results by Scenario ===")
    for scenario, results in results_by_scenario.items():
        total_cases = len(results)
        successful_cases = sum(1 for r in results if r['success'])
        success_rate = (successful_cases / total_cases) * 100 if total_cases > 0 else 0
        avg_turns = sum(r['turns'] for r in results) / total_cases if total_cases > 0 else 0

        print(f"\n{scenario}:")
        print(f"Total cases: {total_cases}")
        print(f"Success rate: {success_rate:.2f}%")
        print(f"Average turns: {avg_turns:.2f}")

    # Run G-Evaluation
    print("\n=== G-Evaluation Results ===")
    detailed_results, scenario_summary = run_evaluation_batch(test_pairs_by_scenario, index)

    # Display scenario summary table
    print("\nScenario Summary:")
    print(scenario_summary.to_string(index=False))

    # Save results
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    # pd.DataFrame(all_results).to_csv(f'multi_turns_results_{timestamp}.csv', index=False)
    detailed_results.to_csv(f'g_evaluation_detailed_{timestamp}.csv', index=False)
    scenario_summary.to_csv(f'g_evaluation_summary_{timestamp}.csv', index=False)

    print(f"G-Evaluation detailed results saved to: g_evaluation_detailed_{timestamp}.csv")
    print(f"G-Evaluation summary saved to: g_evaluation_summary_{timestamp}.csv")

if __name__ == "__main__":
    main()
# Out:
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# D:\anaconda3\envs\ece1786\lib\site-packages\transformers\models\bert\modeling_bert.py:440: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for something comfortable for walking around the city all day."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for something comfortable for walking around the city all day.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for shoes that are easy to slip on and off, comfortable for walking around the city all day."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for shoes that are easy to slip on and off, comfortable for walking around the city all day.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for a versatile shoe that is comfortable for walking around the city all day, easy to slip on and off, and suitable for both casual and slightly dressy outfits."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for a versatile shoe that is comfortable for walking around the city all day, easy to slip on and off, and suitable for both casual and slightly dressy outfits.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for shoes that the user can wear both at the gym and casual outings."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for shoes that the user can wear both at the gym and casual outings.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for supportive shoes suitable for both weightlifting and casual outings."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for supportive shoes suitable for both weightlifting and casual outings.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for shoes with a sleek design that are supportive for weightlifting and suitable for both gym and casual outings."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for shoes with a sleek design that are supportive for weightlifting and suitable for both gym and casual outings.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for shoes suitable for daily morning jogs."
#   ],
#   "colors": [],
#   "categories": [
#     "Running"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for shoes suitable for daily morning jogs.
#
# Extracted Preferences:
# {
#   "query": [
#     "User needs shoes with good grip for jogging in a hilly area."
#   ],
#   "colors": [],
#   "categories": [
#     "Running"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User needs shoes with good grip for jogging in a hilly area.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for brightly colored shoes with good grip for daily morning jogs in a hilly area."
#   ],
#   "colors": [
#     "Yellow"
#   ],
#   "categories": [
#     "Running"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for brightly colored shoes with good grip for daily morning jogs in a hilly area.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user wants shoes that have a vintage yet modern look."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user wants shoes that have a vintage yet modern look.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for shoes with neutral colors like beige or cream, with a vintage yet modern appearance."
#   ],
#   "colors": [],
#   "categories": [],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for shoes with neutral colors like beige or cream, with a vintage yet modern appearance.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user prefers shoes made of leather or suede materials for a classy, vintage yet modern look, and is interested in neutral colors."
#   ],
#   "colors": [
#     "Grey"
#   ],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user prefers shoes made of leather or suede materials for a classy, vintage yet modern look, and is interested in neutral colors.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for sneakers that are stylish but not too flashy."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for sneakers that are stylish but not too flashy.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for stylish sneakers with monotone or subtle two-tone designs that are not too flashy."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for stylish sneakers with monotone or subtle two-tone designs that are not too flashy.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for shoes with cool streetwear vibes."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for shoes with cool streetwear vibes.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user prefers high-top designs for a bold streetwear statement."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user prefers high-top designs for a bold streetwear statement.
#
# Extracted Preferences:
# {
#   "query": [
#     "Interested in shoes with a cool streetwear vibe, high-top designs, and graffiti-style elements for a bold statement."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Interested in shoes with a cool streetwear vibe, high-top designs, and graffiti-style elements for a bold statement.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for supportive shoes due to foot pain after long walks."
#   ],
#   "colors": [],
#   "categories": [
#     "Running"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for supportive shoes due to foot pain after long walks.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for shoes with good cushioning in the heel area and supportive features for long walks."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for shoes with good cushioning in the heel area and supportive features for long walks.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for lightweight, supportive shoes with cushioning, especially in the heel area, for long walks."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle",
#     "Running"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for lightweight, supportive shoes with cushioning, especially in the heel area, for long walks.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for light and breathable shoes suitable for summer."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for light and breathable shoes suitable for summer.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for lightweight and breathable shoes, with a preference for mesh materials, suitable for summer."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for lightweight and breathable shoes, with a preference for mesh materials, suitable for summer.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user prefers pastel-colored, light, and breathable shoes suitable for summer, preferably with mesh materials."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user prefers pastel-colored, light, and breathable shoes suitable for summer, preferably with mesh materials.
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for shoes that prevent feet from getting sweaty."
#   ],
#   "colors": [],
#   "categories": [],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for shoes that prevent feet from getting sweaty.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for shoes with good airflow that prevent feet from becoming sweaty."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for shoes with good airflow that prevent feet from becoming sweaty.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for shoes made of natural materials that wick away moisture to prevent sweaty feet and ensure good airflow."
#   ],
#   "colors": [],
#   "categories": [],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for shoes made of natural materials that wick away moisture to prevent sweaty feet and ensure good airflow.
#
# Extracted Preferences:
# {
#   "query": [
#     "Need sneakers that are appropriate for work and also have a cool style."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Need sneakers that are appropriate for work and also have a cool style.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for black or navy sneakers that are suitable for work and have a cool style."
#   ],
#   "colors": [
#     "Black"
#   ],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for black or navy sneakers that are suitable for work and have a cool style.
#
# Extracted Preferences:
# {
#   "query": [
#     "Want something suitable for both indoor and outdoor activities."
#   ],
#   "colors": [],
#   "categories": [],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Want something suitable for both indoor and outdoor activities.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for shoes with a durable sole for outdoor activities, also suitable for indoor use."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for shoes with a durable sole for outdoor activities, also suitable for indoor use.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user wants shoes that are easy to clean and suitable for both indoor and outdoor activities with a durable sole."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user wants shoes that are easy to clean and suitable for both indoor and outdoor activities with a durable sole.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for shoes suitable for casual parties."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for shoes suitable for casual parties.
#
# Extracted Preferences:
# {
#   "query": [
#     "Looking for shiny or metallic-accented shoes for casual parties."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  Looking for shiny or metallic-accented shoes for casual parties.
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for low-top sneakers for a laid-back look that can be worn to casual parties, with a preference for something shiny or with a metallic accent."
#   ],
#   "colors": [],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking

#   "categories": [],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is interested in shoes with a mid-top design, suitable for spring weather, preferably in light colors such as pastel greens or blues to match the spring vibe.
#
# === Test Results by Scenario ===
#
# Activity/Purpose Based:
# Total cases: 3
# Success rate: 33.33%
# Average turns: 3.00
#
# Style/Appearance Based:
# Total cases: 3
# Success rate: 33.33%
# Average turns: 2.67
#
# Comfort/Experience Based:
# Total cases: 3
# Success rate: 33.33%
# Average turns: 3.00
#
# Occasion Based:
# Total cases: 3
# Success rate: 100.00%
# Average turns: 2.67
#
# Mixed Requirements:
# Total cases: 3
# Success rate: 66.67%
# Average turns: 3.00
#
# Specific Problem Based:
# Total cases: 3
# Success rate: 100.00%
# Average turns: 3.00
#
# Weather/Season Based:
# Total cases: 3
# Success rate: 100.00%
# Average turns: 2.33
#
# === G-Evaluation Results ===
# Token indices sequence length is longer than the specified maximum sequence length for this model (276 > 128). Running this sequence through the model will result in indexing errors
# Extracted Preferences:
# {
#   "query": [
#     "The user is introduced to the Vans Classic Slip-On 'Black White' as a versatile sneaker suitable for city adventures, combining style, comfort, and practicality."
#   ],
#   "colors": [
#     "Black",
#     "White"
#   ],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "1"
#   ]
# }
# Summary:  The user is introduced to the Vans Classic Slip-On 'Black White' as a versatile sneaker suitable for city adventures, combining style, comfort, and practicality.
# IndexError: Result index out of range for input: Hey there! It sounds like you're on the hunt for a super versatile sneaker that can keep up with your city adventures and style needs. Let me introduce you to the Vans Classic Slip-On 'Black White.' This sneaker is a fantastic match for what you're looking for.
#
# First off, the slip-on design makes them incredibly easy to put on and take off, perfect for those busy days when you're constantly on the go. The durable black canvas upper not only adds a touch of sleek simplicity that pairs effortlessly with both casual and slightly dressy outfits, but it’s also built to withstand the hustle and bustle of city life.
#
# Comfort is key when you're walking around all day, and the padded collars on these Vans provide that extra cushioning to keep your feet happy from morning till night. Plus, the signature gum waffle outsole gives you reliable traction, ensuring stability on various surfaces as you explore the city.
#
# And let's not forget the iconic Vans Off-the-Wall bumper logo, adding a stylish flair that makes these sneakers stand out just enough while still being versatile.
#
# With the Vans Classic Slip-On 'Black White,' you're getting a blend of style, comfort, and practicality that suits your lifestyle perfectly. Enjoy your city adventures in style and comfort!
# Error details: index out of range in self
#
# Extracted Preferences:
# {
#   "query": [
#     "User is looking for a sneaker that blends style with functionality for weightlifting and casual outings, specifically interested in the Nike Dunk Low Next Nature Baroque Brown."
#   ],
#   "colors": [
#     "Brown",
#     "Black",
#     "White"
#   ],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  User is looking for a sneaker that blends style with functionality for weightlifting and casual outings, specifically interested in the Nike Dunk Low Next Nature Baroque Brown.
# IndexError: Result index out of range for input: Hey there! It sounds like you're on the hunt for a sneaker that perfectly blends style with functionality, especially for weightlifting and casual outings. Let me introduce you to the Nike Dunk Low Next Nature Baroque Brown—an excellent match for your needs.
#
# First off, this sneaker boasts a sleek, classic Dunk Low design that's bound to turn heads, whether you're hitting the gym or just out and about. The Baroque Brown and black hues give it a versatile look that easily transitions from workout gear to everyday wear.
#
# Now, let's talk about support. While the Dunk Low is traditionally a lifestyle sneaker, its construction offers a sturdy base. The synthetic tumbled leather and synthetic suede overlays provide a snug fit, which can contribute to the stability you need during weightlifting sessions.
#
# Additionally, the use of recycled materials not only adds to the shoe's durability but also makes it a choice you can feel good about, considering sustainability. The robust white and black rubber outsole ensures you have the grip you need, whether you're lifting or striding down the street.
#
# Overall, the Nike Dunk Low Next Nature Baroque Brown is not just a sneaker; it's a statement of style and function, seamlessly fitting into both your gym and casual life. Enjoy making every step count!
# Error details: index out of range in self
#
# Extracted Preferences:
# {
#   "query": [
#     "The user
# Error details: index out of range in self
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is interested in the Nike SB Dunk Low Premium City of Style due to its artistic graffiti-style elements, unique color combination of khaki, Flat Gold, and light brown, and its streetwear vibe."
#   ],
#   "colors": [
#     "Brown",
#     "Yellow"
#   ],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "1"
#   ]
# }
# Summary:  The user is interested in the Nike SB Dunk Low Premium City of Style due to its artistic graffiti-style elements, unique color combination of khaki, Flat Gold, and light brown, and its streetwear vibe.
# IndexError: Result index out of range for input: Hey there! It sounds like you're on the hunt for something that really stands out with a bold streetwear vibe, and I think the Nike SB Dunk Low Premium City of Style might just hit the mark for you. While it's a low-top design, this sneaker is packed with the kind of artistic flair you're after.
#
# First off, the design on this shoe is something special—it features graffiti-style elements with scenes of nature creatively woven into the fabric of the shoe. The illustrations of clouds, trees, and graffitied walls are outlined in a striking combination of khaki, Flat Gold, and light brown, giving it a unique edge that screams urban artistry.
#
# You'll appreciate the high-quality leather upper, which not only adds to the durability of the shoe but also gives it a premium feel that complements its stylish look. And let's not overlook the subtle "SB" branding integrated into the graffiti illustrations—it's like carrying a piece of street art with you wherever you go.
#
# Additionally, the Nike branding stitched in gold on the heel and the brown/gold SB patch on the tongue add extra pops of color that enhance its bold statement. Whether you're pairing these with your favorite streetwear outfit or making them the centerpiece of your look, these sneakers are sure to turn heads.
#
# Overall, the Nike SB Dunk Low Premium City of Style isn't just a sneaker—it's a canvas of style and creativity, perfectly aligned with your desire for something with a cool streetwear vibe. Hope this helps and that you enjoy making a statement
# Error details: index out of range in self
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for comfortable shoes for long walks, focusing on support and cushioning. They are considering the ASICS Gel-Kayano 14 in Cream Black Metallic Plum, which offers a stable and cushioned experience."
#   ],
#   "colors": [
#     "Black"
#   ],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for comfortable shoes for long walks, focusing on support and cushioning. They are considering the ASICS Gel-Kayano 14 in Cream Black Metallic Plum, which offers a stable and cushioned experience.
# IndexError: Result index out of range for input: Hey there! It sounds like you're planning on some long walks, and comfort is key. The ASICS Gel-Kayano 14 Cream Black Metallic Plum could be just what you're looking for. This shoe is designed with a focus on support and cushioning, which is perfect for those extended strolls.
#
# One of the standout features is the dynamic DuoMax support system. This will give you the stability you need, especially if you tend to overpronate, which helps make each step more efficient. Plus, the Gel technology in the heel is a game-changer for cushioning. It’s specifically designed to absorb impact, meaning your feet will feel less fatigued and more energized, even after long distances.
#
# The combination of leather and mesh in the upper provides durability and breathability, keeping your feet comfortable and cool during long walks. And with its classic lace-up closure, you can count on a secure fit, letting you focus on enjoying your journey without constantly adjusting your shoes.
#
# Overall, the ASICS Gel-Kayano 14 offers a blend of support, cushioning, and comfort, tailored for those who love to walk for miles. Happy walking!
# Error details: index out of range in self
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is considering the Jordan 4 Retro SE Craft Medium Olive, appreciating its unique earthy colors, comfort, and performance features for summer, despite it lacking the pastel hues they initially sought."
#   ],
#   "colors": [
#     "Green"
#   ],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user
# Error details: index out of range in self
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is considering Vans Classic Slip-On sneakers in Black for work shifts due to their slip-resistance and cushioning features."
#   ],
#   "colors": [
#     "Black",
#     "White"
#   ],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "1"
#   ]
# }
# Summary:  The user is considering Vans Classic Slip-On sneakers in Black for work shifts due to their slip-resistance and cushioning features.
# IndexError: Result index out of range for input: Hey there! If you're gearing up for those long work shifts and need a pair of sneakers that offer both slip-resistance and cushioning, the Vans Classic Slip-On 'Black White' could be just what you're looking for.
#
# These sneakers boast Vans' signature gum waffle outsole, which is renowned for providing excellent traction. This means you can count on stable footing even on slippery surfaces, making them a great choice for work environments where slip-resistance is key.
#
# Additionally, the padded collars of these slip-ons provide a comfortable fit, offering that extra cushioning support you need to keep your feet feeling good all day long. Plus, with their easy slip-on design, they're super convenient for quick on-and-off action, letting you focus on your tasks without any hassle.
#
# Whether you're standing or moving around a lot during your shifts, the combination of comfort and grip in these sneakers is designed to keep you steady and comfy. Plus, their classic black canvas upper ensures they’ll easily match any work attire while giving you that timeless Vans style. Enjoy your shifts with confidence and comfort!
# Error details: index out of range in self
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for stylish and waterproof sneakers suitable for rainy weather, specifically considering the Nike ACG Air Zoom Gaiadome Gore-Tex Trails End Brown, which features Gore-Tex waterproofing and rugged design elements for versatility and comfort."
#   ],
#   "colors": [
#     "Brown",
#     "Black"
#   ],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "1"
#   ]
# }
# Summary:  The user is looking for stylish and waterproof sneakers suitable for rainy weather, specifically considering the Nike ACG Air Zoom Gaiadome Gore-Tex Trails End Brown, which features Gore-Tex waterproofing and rugged design elements for versatility and comfort.
# IndexError: Result index out of range for input: Hey there! It sounds like you're looking for a sneaker that can handle rainy weather while still looking stylish, and the Nike ACG Air Zoom Gaiadome Gore-Tex Trails End Brown is a fantastic choice for you.
#
# This sneaker is part of Nike's All Conditions Gear collection, specifically designed to keep your feet dry and comfortable, no matter the weather. The Gore-Tex finish on the brown and black upper is a standout feature that ensures waterproof protection, so you can step through puddles or drizzling rain without a worry.
#
# Beyond its practicality, the design is rugged yet sleek, making it a versatile addition to your wardrobe. The metal eye stays and lacing clasps not only add a touch of sophistication but also keep your foot snug and secure. Plus, the reflective flecks in the laces add a bit of flair, making sure you stand out, even in lower light conditions.
#
# Comfort isn't compromised either, thanks to Nike's Air Zoom technology which absorbs impact, providing a cushioned ride whether you're exploring the city or hiking trails. The durable plastic shank in the midfoot offers added stability, giving you confidence with each step.
#
# Overall, the Nike ACG Air Zoom Gaiadome is perfect for those rainy days when you want to stay dry while maintaining a stylish edge. It's a reliable and fashionable option that meets your needs beautifully. Enjoy your adventures, rain or shine!
# Error details: index out of range in self
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is looking for summer sneakers that are comfortable, breathable, and stylish, particularly in vibrant colors like yellow. They are interested in Nike Dunk Low 'Team Gold' sneakers."
#   ],
#   "colors": [
#     "Yellow"
#   ],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is looking for summer sneakers that are comfortable, breathable, and stylish, particularly in vibrant colors like yellow. They are interested in Nike Dunk Low 'Team Gold' sneakers.
# IndexError: Result index out of range for input: Hey there! It sounds like you're on the hunt for the perfect sneakers to keep you cool and comfortable during those hot summer days, and I think the Nike Dunk Low 'Team Gold' might just be what you're looking for.
#
# Let's talk about breathability first—one of the key features here is the perforated detailing at the toe box. This is designed to increase airflow, helping your feet stay cool and fresh even when the temperature rises. The low-profile design, complemented by a padded low-cut collar, not only adds to the comfort but also ensures a snug, enjoyable fit all day long.
#
# When it comes to style, these sneakers have you covered with their eye-catching yellow overlays. They offer a bright, sunny vibe that's perfect for summer, and while the color might be described as "Team Gold," it definitely brings that pop of vibrant color you're after. It's a great match for your preference for bright summer shades like orange or yellow.
#
# Lastly, the durable rubber cupsole and interior foam wedge provide lightweight cushioning, making sure your steps are not only stylish but also cushioned and supported. This means you can walk around comfortably, whether you're hitting the streets or just enjoying a casual day out.
#
# I really think the Nike Dunk Low 'Team Gold' checks all your boxes for comfort, breathability, and vibrant style. They're ready to make your summer outings both cool and colorful!
# Error details: index out of range in self
#
# Extracted Preferences:
# {
#   "query": [
#     "The user is interested in the April Skateboards x Nike Dunk Low SB 'Turbo Green', highlighting its style, support, and vibrant colors suitable for spring."
#   ],
#   "colors": [
#     "White",
#     "Green"
#   ],
#   "categories": [
#     "Lifestyle"
#   ],
#   "end_flag": [
#     "0"
#   ]
# }
# Summary:  The user is interested in the April Skateboards x Nike Dunk Low SB 'Turbo Green', highlighting its style, support, and vibrant colors suitable for spring.
# IndexError: Result index out of range for input: Hey there! It sounds like you're looking for something fresh and vibrant to step into the spring season. The April Skateboards x Nike Dunk Low SB 'Turbo Green' could be just what you're after.
#
# This sneaker offers a mid-top design that balances style and support perfectly, ideal for those breezy spring days. The airy white mesh upper will keep your feet cool, while the bright teal suede overlays add a splash of color that’s just right for spring. The pastel-like Turbo Green gives off a fresh vibe, perfect for matching the lively colors of the season.
#
# Additionally, the chrome Swoosh and unique floral graphic on the translucent rubber outsole not only enhance the sneaker's aesthetic but also bring a touch of nature-inspired elegance to your look. Plus, the durable materials ensure that these shoes will stand up to your spring adventures. Whether you're out for a casual stroll or meeting up with friends, these sneakers will keep you comfortable and stylish. Enjoy stepping into spring with a vibrant flair!
# Error details: index out of range in self
#
# Scenario Summary:
#                 Scenario  Average Relevance  Average Completeness  Average Personalization  Average Expertise  Average Language  Overall Average
#   Activity/Purpose Based           4.250000              4.750000                 3.500000           4.250000          5.000000         4.350000
#   Style/Appearance Based           4.000000              4.333333                 3.500000           4.333333          4.500000         4.133333
# Comfort/Experience Based           3.333333              3.833333                 2.833333           4.000000          4.333333         3.666667
#           Occasion Based           4.333333              4.166667                 3.500000           4.333333          4.666667         4.200000
#       Mixed Requirements           4.000000              4.333333                 3.500000           4.500000          4.833333         4.233333
#   Specific Problem Based           4.166667              4.333333                 3.333333           4.333333          4.500000         4.133333
#     Weather/Season Based           4.166667              3.833333                 3.666667           4.166667          4.666667         4.100000
# G-Evaluation detailed results saved to: g_evaluation_detailed_20241126_075052.csv
# G-Evaluation summary saved to: g_evaluation_summary_20241126_075052.csv
